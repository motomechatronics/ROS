# %% [markdown]
# # Basic Bash guide

# %% [markdown]
# ## Description
# visit https://tldp.org/LDP/Bash-Beginners-Guide/html/ or follow this guide to learn the basic concepts useful for working in Ubuntu.

# %% [markdown]
# ### installation prerequisite
# 1. a version of UBUNTU 18.04 LTS available on PC;
# 2. a version of UBUNTU 18.04 LTS available on virtual machine.

# %% [markdown]
# ## 1. How to navigate through a Linux filesystem

# %% [markdown]
# Use _pwd_ to show position between folders. An example of using _pwd_ command is shown below:

# %%
pwd
# Out:
# '/home/jovyan/demo'

# %% [markdown]
# Use _cd_ to navigate through the folders. Below is an example of using _cd_:

# %%
cd /home/jovyan/
# Out:
# /home/jovyan

# %% [markdown]
# To go to a previous folder, for example from _jovian_ to _home_, type:

# %%
cd ..
# Out:
# /home

# %% [markdown]
# View the contents of a directory by typing:

# %%
ls
# Out:
# jovyan/  shiny/

# %% [markdown]
# To show hidden files

# %%
ls -la
# Out:
# total 24
# drwxr-xr-x 1 root   root   4096 Oct 16 10:27 ./
# drwxr-xr-x 1 root   root   4096 Dec 12 22:05 ../
# drwxr-xr-x 1 jovyan jovyan 4096 Dec 12 22:06 jovyan/
# drwxr-xr-x 2 shiny  shiny  4096 Oct 16 10:27 shiny/

# %% [markdown]
# ## 2. How to interact with Linux filesystem

# %% [markdown]
# Create a directory typing:

# %%
mkdir example_directory

# %% [markdown]
# You can create a file inside the _example_directory_ folder by _touch_ command:

# %%
cd example_directory

# %%
touch myfile

# %% [markdown]
# ## 3. How to manage folders and files

# %% [markdown]
# To rename or move a file, use the _mv_ command as follows. Often it is necessary to use this command in conjunction with _sudo_. To rename _myfile_ name to _newfile_:

# %%
sudo mv myfile newfile

# %% [markdown]
# To copy myfile from the _home_ directory to _jovyan_:

# %%
sudo cp myfile /jovyan

# %% [markdown]
# To copy _myfolder_ from the _home_ directory to _jovyan_:

# %%
sudo cp -r home/ jovyan/

# %% [markdown]
# Similarly, to delete files and folders:

# %%
sudo rm myfile

# %%
sudo rm -r myfolder

# %% [markdown]
# ## 4. How to edit files using the shell

# %% [markdown]
# In Ubuntu, there are several text editors such as _nano_, _gedit_ or _vi_. You can use the latest to edit previous my_file:

# %%
vi myfile

# %% [markdown]
# Inside _vi_, you can:
# - to type the _i_ letter to insert the text;
# - press _esc_ botton to exit from insert mode;
# - to type _:w_ to save;
# - to type _:q_ to exit from _vi_;
# - to type _:wq_ to save and exit.

# %% [markdown]
# ## 5. Manage access to files

# %% [markdown]
# Finally, you can give _myfile_ execute permission using the _chmod_ command as follows. Often it is necessary to use this command in conjunction with _sudo_.

# %%
sudo chmod +x myfile
